# %% [markdown]
# In this notebook quantum_ucc_ansatz.py is used to generate dissociation curves

# %%
import quantum_UCC_ansatz as qucca

import numpy as np

from qiskit_nature.second_q.drivers import PySCFDriver

from pyscf import gto, cc, dft, scf
from pyscf.fci import FCI

import psi4
from CID_code import calculate_CID

import pickle

# %% [markdown]
# Defining the linspace

# %%
lin = np.linspace(0.4, 4.5, 5)

# %%
# classical_CC = []
UCCS = []
pUCCD = []
pUCCSD = []

classical_CCSD = []
classical_CCSD_T = []

# comp_UCCS = []
# comp_pUCCD = []
# comp_pUCCSD = []

fci = []
cid = []
hf = []

for r in lin:

    print("-"*20, f"\nr = {r}\n", "-"*20)

    driver = PySCFDriver(atom=f"H 0 0 0; H 0 0 {r}", spin=0, basis="sto-3g")
    mol = driver.run()

    # singles
    print("UCCS")
    ansatz = qucca.CustomAnsatz(mol, singles=True)
    UCCS.append(qucca.solve(mol, ansatz.circuit))

    # # compressed singles
    # ansatz = qucca.CustomAnsatz(mol)
    # for exc in ansatz.generate_CCS_excitations():
    #     ansatz.add_compressed_single(exc[0], exc[1])
    # comp_UCCS.append(qucca.solve(mol, ansatz.circuit))

    # pair doubles
    print("pUCCD")
    ansatz = qucca.CustomAnsatz(mol, pair_doubles=True)
    pUCCD.append(qucca.solve(mol, ansatz.circuit))

    # # compressed pair doubles
    # ansatz = qucca.CustomAnsatz(mol)
    # for exc in ansatz.generate_pCCD_excitations():
    #     ansatz.add_compressed_double(exc[0], exc[1])
    # comp_pUCCD.append(qucca.solve(mol, ansatz.circuit))

    # singles & pair doubles
    print("pUCCSD")
    ansatz = qucca.CustomAnsatz(mol, singles=True, pair_doubles=True)
    pUCCSD.append(qucca.solve(mol, ansatz.circuit))

    # # compressed UpCCSD
    # ansatz = qucca.CustomAnsatz(mol)
    # for exc in ansatz.generate_CCS_excitations():
    #     ansatz.add_compressed_single(exc[0], exc[1])
    # for exc in ansatz.generate_pCCD_excitations():
    #     ansatz.add_compressed_double(exc[0], exc[1])
    # comp_pUCCSD.append(qucca.solve(mol, ansatz.circuit))


    mol = gto.Mole()
    mol.atom = f"H 0 0 0; H 0 0 {r}"
    mol.basis = 'sto-3g'
    mol.spin=0
    mol.build()

    # fci
    print("fci")
    mf = mol.RHF().run()
    cisolver = FCI(mf)
    fci.append(cisolver.kernel()[0])

    # hf
    print("hf")
    mf = scf.RHF(mol)
    hf.append(mf.kernel())

    # cc
    mf = scf.HF(mol).run()
    # Note that the line following these comments could be replaced by
    # mycc = cc.CCSD(mf)
    # mycc.kernel()
    mycc = cc.CCSD(mf).run()
    classical_CCSD.append(mycc.e_tot)
    et = mycc.ccsd_t()
    classical_CCSD_T.append(mycc.e_tot + et)


    mol = psi4.geometry(f"""
                        H 0 0 0
                        H 0 0 {r}
                        symmetry c1
                        """)

    psi4.set_options({'basis': 'sto-3g',
                    'scf_type': 'pk',
                    'e_convergence': 1e-8,
                    'd_convergence': 1e-8})

    scf_e, wfn = psi4.energy('SCF', return_wfn=True)
    cid.append(calculate_CID(mol, scf_e, wfn))
# Out:
# --------------------
# r = 0.4
#  --------------------
# UCCS
# /usr/local/miniconda3/lib/python3.7/site-packages/qiskit_nature/deprecation.py:297: PauliSumOpDeprecationWarning: PauliSumOp is deprecated as of version 0.6.0 and support for them will be removed no sooner than 3 months after the release. Instead, use SparsePauliOp. You can switch to SparsePauliOp immediately, by setting `qiskit_nature.settings.use_pauli_sum_op` to `False`.
#   return func(*args, **kwargs)
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.90436139416354
# hf
# converged SCF energy = -0.90436139416354
# converged SCF energy = -0.90436139416354
# E(CCSD) = -0.9141497227610512  E_corr = -0.009788328597511399
# CCSD(T) correction = -5.72138477802078e-47
# --------------------
# r = 0.48367346938775513
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.02734534131493
# hf
# converged SCF energy = -1.02734534131493
# converged SCF energy = -1.02734534131493
# E(CCSD) = -1.039080519068971  E_corr = -0.01173517775404329
# CCSD(T) correction = 0
# --------------------
# r = 0.5673469387755102
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.08807418906478
# hf
# converged SCF energy = -1.08807418906478
# converged SCF energy = -1.08807418906478
# E(CCSD) = -1.102182187657011  E_corr = -0.01410799859222973
# CCSD(T) correction = 7.88729472816514e-50
# --------------------
# r = 0.6510204081632653
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.11315276658124
# hf
# converged SCF energy = -1.11315276658124
# converged SCF energy = -1.11315276658124
# E(CCSD) = -1.130098696609878  E_corr = -0.01694593002864141
# CCSD(T) correction = 1.57776495009003e-49
# --------------------
# r = 0.7346938775510203
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.11701223704794
# hf
# converged SCF energy = -1.11701223704794
# converged SCF energy = -1.11701223704794
# E(CCSD) = -1.137306183450634  E_corr = -0.02029394640269501
# CCSD(T) correction = 0
# --------------------
# r = 0.8183673469387756
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.10809323037187
# hf
# converged SCF energy = -1.10809323037187
# converged SCF energy = -1.10809323037187
# E(CCSD) = -1.132302186897826  E_corr = -0.0242089565259587
# CCSD(T) correction = -6.65705076586916e-48
# --------------------
# r = 0.9020408163265305
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.09144249826248
# hf
# converged SCF energy = -1.09144249826248
# converged SCF energy = -1.09144249826248
# E(CCSD) = -1.12020822336806  E_corr = -0.02876572510557923
# CCSD(T) correction = 8.2396454353243e-50
# --------------------
# r = 0.9857142857142857
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.07008090367043
# hf
# converged SCF energy = -1.07008090367043
# converged SCF energy = -1.07008090367043
# E(CCSD) = -1.104138385846873  E_corr = -0.0340574821764455
# CCSD(T) correction = -8.29618737431437e-49
# --------------------
# r = 1.0693877551020408
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.04586138991663
# hf
# converged SCF energy = -1.04586138991663
# converged SCF energy = -1.04586138991663
# E(CCSD) = -1.086046058416033  E_corr = -0.04018466849939969
# CCSD(T) correction = -1.45319519019441e-48
# --------------------
# r = 1.1530612244897958
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -1.01999978727946
# hf
# converged SCF energy = -1.01999978727946
# converged SCF energy = -1.01999978727946
# E(CCSD) = -1.06724074602023  E_corr = -0.04724095874076908
# CCSD(T) correction = -3.61684827403157e-48
# --------------------
# r = 1.236734693877551
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.99336261478504
# hf
# converged SCF energy = -0.99336261478504
# converged SCF energy = -0.99336261478504
# E(CCSD) = -1.048659963295659  E_corr = -0.05529734851061926
# CCSD(T) correction = 0
# --------------------
# r = 1.3204081632653062
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.966600801671198
# hf
# converged SCF energy = -0.966600801671198
# converged SCF energy = -0.966600801671198
# E(CCSD) = -1.030989541318182  E_corr = -0.06438873964698383
# CCSD(T) correction = 0
# --------------------
# r = 1.4040816326530612
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.940207716312335
# hf
# converged SCF energy = -0.940207716312335
# converged SCF energy = -0.940207716312335
# E(CCSD) = -1.014711758864032  E_corr = -0.07450404255169703
# CCSD(T) correction = 0
# --------------------
# r = 1.4877551020408162
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.914549781060909
# hf
# converged SCF energy = -0.914549781060909
# converged SCF energy = -0.914549781060909
# E(CCSD) = -1.000130276121203  E_corr = -0.08558049506029383
# CCSD(T) correction = 0
# --------------------
# r = 1.5714285714285712
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.889889958374527
# hf
# converged SCF energy = -0.889889958374527
# converged SCF energy = -0.889889958374527
# E(CCSD) = -0.9873930560163031  E_corr = -0.09750309764177562
# CCSD(T) correction = 0
# --------------------
# r = 1.6551020408163266
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.866408765974939
# hf
# converged SCF energy = -0.866408765974939
# converged SCF energy = -0.866408765974939
# E(CCSD) = -0.976518785827806  E_corr = -0.1101100198528672
# CCSD(T) correction = -1.08118838268953e-47
# --------------------
# r = 1.7387755102040816
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.84422227801639
# hf
# converged SCF energy = -0.84422227801639
# converged SCF energy = -0.84422227801639
# E(CCSD) = -0.9674262911372458  E_corr = -0.1232040131208561
# CCSD(T) correction = 0
# --------------------
# r = 1.8224489795918366
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.82339638395541
# hf
# converged SCF energy = -0.82339638395541
# converged SCF energy = -0.82339638395541
# E(CCSD) = -0.9599647885477691  E_corr = -0.1365684045923586
# CCSD(T) correction = 2.97181567449985e-47
# --------------------
# r = 1.9061224489795916
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.803957584780605
# hf
# converged SCF energy = -0.803957584780605
# converged SCF energy = -0.803957584780605
# E(CCSD) = -0.9539424908740638  E_corr = -0.1499849060934591
# CCSD(T) correction = 0
# --------------------
# r = 1.9897959183673466
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.785901254663855
# hf
# converged SCF energy = -0.785901254663855
# converged SCF energy = -0.785901254663855
# E(CCSD) = -0.9491512582257936  E_corr = -0.163250003561939
# CCSD(T) correction = 0
# --------------------
# r = 2.073469387755102
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.769198355160242
# hf
# converged SCF energy = -0.769198355160242
# converged SCF energy = -0.769198355160242
# E(CCSD) = -0.9453856773968227  E_corr = -0.1761873222365803
# CCSD(T) correction = -5.13072038822146e-47
# --------------------
# r = 2.157142857142857
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.753801289850995
# hf
# converged SCF energy = -0.753801289850995
# converged SCF energy = -0.753801289850995
# E(CCSD) = -0.9424559970342861  E_corr = -0.1886547071832912
# CCSD(T) correction = 0
# --------------------
# r = 2.240816326530612
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.739649200460947
# hf
# converged SCF energy = -0.739649200460947
# converged SCF energy = -0.739649200460947
# E(CCSD) = -0.9401953716276745  E_corr = -0.2005461711667274
# CCSD(T) correction = 8.89700071538437e-46
# --------------------
# r = 2.324489795918367
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.726672706630371
# hf
# converged SCF energy = -0.726672706630371
# converged SCF energy = -0.726672706630371
# E(CCSD) = -0.9384625533904855  E_corr = -0.2117898467601147
# CCSD(T) correction = 6.42859977916364e-46
# --------------------
# r = 2.408163265306122
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.714797947934126
# hf
# converged SCF energy = -0.714797947934126
# converged SCF energy = -0.714797947934126
# E(CCSD) = -0.9371416037892203  E_corr = -0.222343655855094
# CCSD(T) correction = 0
# --------------------
# r = 2.491836734693877
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.703949785469555
# hf
# converged SCF energy = -0.703949785469555
# converged SCF energy = -0.703949785469555
# E(CCSD) = -0.936138619574614  E_corr = -0.2321888341050591
# CCSD(T) correction = 4.37844636633715e-44
# --------------------
# r = 2.5755102040816324
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.694054106855205
# hf
# converged SCF energy = -0.694054106855205
# converged SCF energy = -0.694054106855205
# E(CCSD) = -0.9353802503620916  E_corr = -0.2413261435068868
# CCSD(T) correction = 5.80296950479411e-44
# --------------------
# r = 2.6591836734693874
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.685039290990383
# hf
# converged SCF energy = -0.685039290990383
# converged SCF energy = -0.685039290990383
# E(CCSD) = -0.9348090911985798  E_corr = -0.2497698002081969
# CCSD(T) correction = 7.92205581103647e-46
# --------------------
# r = 2.7428571428571424
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.676836980611817
# hf
# converged SCF energy = -0.676836980611817
# converged SCF energy = -0.676836980611817
# E(CCSD) = -0.9343801763591396  E_corr = -0.2575431957473228
# CCSD(T) correction = 5.34498984150009e-44
# --------------------
# r = 2.8265306122448974
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.669382358309329
# hf
# converged SCF energy = -0.669382358309329
# converged SCF energy = -0.669382358309329
# E(CCSD) = -0.9340593278109985  E_corr = -0.2646769695016699
# CCSD(T) correction = 7.85407188761736e-46
# --------------------
# r = 2.910204081632653
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.66261412340719
# hf
# converged SCF energy = -0.66261412340719
# converged SCF energy = -0.66261412340719
# E(CCSD) = -0.9338202516807688  E_corr = -0.2712061282735789
# CCSD(T) correction = -9.838160273154e-43
# --------------------
# r = 2.993877551020408
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.656474334823566
# hf
# converged SCF energy = -0.656474334823566
# converged SCF energy = -0.656474334823566
# E(CCSD) = -0.9336428500954977  E_corr = -0.2771685152719322
# CCSD(T) correction = 0
# --------------------
# r = 3.077551020408163
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.65090823555377
# hf
# converged SCF energy = -0.65090823555377
# converged SCF energy = -0.65090823555377
# E(CCSD) = -0.9335117962083539  E_corr = -0.2826035606545838
# CCSD(T) correction = 0
# --------------------
# r = 3.161224489795918
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.645864123133487
# hf
# converged SCF energy = -0.645864123133487
# converged SCF energy = -0.645864123133487
# E(CCSD) = -0.9334154301797535  E_corr = -0.2875513070462666
# CCSD(T) correction = 0
# --------------------
# r = 3.244897959183673
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.641293287744429
# hf
# converged SCF energy = -0.641293287744429
# converged SCF energy = -0.641293287744429
# E(CCSD) = -0.9333449092007159  E_corr = -0.2920516214562865
# CCSD(T) correction = 0
# --------------------
# r = 3.3285714285714283
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.637150010342466
# hf
# converged SCF energy = -0.637150010342466
# converged SCF energy = -0.637150010342466
# E(CCSD) = -0.9332935531626734  E_corr = -0.2961435428202076
# CCSD(T) correction = 1.18363373879363e-41
# --------------------
# r = 3.4122448979591833
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.633391597594472
# hf
# converged SCF energy = -0.633391597594472
# converged SCF energy = -0.633391597594472
# E(CCSD) = -0.9332563381172122  E_corr = -0.2998647405227403
# CCSD(T) correction = 1.02395411292432e-40
# --------------------
# r = 3.4959183673469383
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.62997842598449
# hf
# converged SCF energy = -0.62997842598449
# converged SCF energy = -0.62997842598449
# E(CCSD) = -0.9332292941688388  E_corr = -0.3032508681843483
# CCSD(T) correction = -1.14187431880429e-40
# --------------------
# r = 3.5795918367346933
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.626873970539768
# hf
# converged SCF energy = -0.626873970539768
# converged SCF energy = -0.626873970539768
# E(CCSD) = -0.9332102412726324  E_corr = -0.3063362707328646
# CCSD(T) correction = 1.89339488736641e-40
# --------------------
# r = 3.6632653061224487
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.624044800658161
# hf
# converged SCF energy = -0.624044800658161
# converged SCF energy = -0.624044800658161
# E(CCSD) = -0.9331964876211079  E_corr = -0.3091516869629472
# CCSD(T) correction = 0
# --------------------
# r = 3.7469387755102037
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.6214605336611
# hf
# converged SCF energy = -0.6214605336611
# converged SCF energy = -0.6214605336611
# E(CCSD) = -0.9331867221824915  E_corr = -0.3117261885213919
# CCSD(T) correction = 0
# --------------------
# r = 3.8306122448979587
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.619093744085948
# hf
# converged SCF energy = -0.619093744085948
# converged SCF energy = -0.619093744085948
# E(CCSD) = -0.9331798650827194  E_corr = -0.3140861209967713
# CCSD(T) correction = -9.72874902952977e-41
# --------------------
# r = 3.9142857142857137
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.616919832399016
# hf
# converged SCF energy = -0.616919832399016
# converged SCF energy = -0.616919832399016
# E(CCSD) = -0.9331748652672303  E_corr = -0.3162550328682147
# CCSD(T) correction = 9.12015661867944e-39
# --------------------
# r = 3.9979591836734687
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.61491686046778
# hf
# converged SCF energy = -0.61491686046778
# converged SCF energy = -0.61491686046778
# E(CCSD) = -0.9331714318387266  E_corr = -0.3182545713709469
# CCSD(T) correction = 9.37366711461692e-39
# --------------------
# r = 4.081632653061225
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.613065362929651
# hf
# converged SCF energy = -0.613065362929651
# converged SCF energy = -0.613065362929651
# E(CCSD) = -0.9331690297871065  E_corr = -0.3201036668574551
# CCSD(T) correction = -2.09468496395398e-40
# --------------------
# r = 4.165306122448979
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.611348143912005
# hf
# converged SCF energy = -0.611348143912005
# converged SCF energy = -0.611348143912005
# E(CCSD) = -0.9331673576683264  E_corr = -0.3218192137563216
# CCSD(T) correction = -7.64161887026222e-37
# --------------------
# r = 4.248979591836735
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.609750067841232
# hf
# converged SCF energy = -0.609750067841232
# converged SCF energy = -0.609750067841232
# E(CCSD) = -0.9331661990203806  E_corr = -0.3234161311791488
# CCSD(T) correction = 9.32916295497544e-39
# --------------------
# r = 4.332653061224489
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.608257851746856
# hf
# converged SCF energy = -0.608257851746856
# converged SCF energy = -0.608257851746856
# E(CCSD) = -0.9331653965253827  E_corr = -0.3249075447785265
# CCSD(T) correction = -6.22460116287638e-37
# --------------------
# r = 4.416326530612245
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.606859864862743
# hf
# converged SCF energy = -0.606859864862743
# converged SCF energy = -0.606859864862743
# E(CCSD) = -0.9331648461170534  E_corr = -0.3263049812543106
# CCSD(T) correction = 2.30524982566956e-36
# --------------------
# r = 4.5
#  --------------------
# UCCS
# pUCCD
# pUCCSD
# fci
# converged SCF energy = -0.605545939700977
# hf
# converged SCF energy = -0.605545939700977
# converged SCF energy = -0.605545939700977
# E(CCSD) = -0.9331644694145356  E_corr = -0.3276185297135586
# CCSD(T) correction = -7.25937295562181e-38

# %%
# from datetime import datetime
# import pickle
# import os


# now = datetime.now()

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_lin")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(lin, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_UCCS")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(UCCS, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_pUCCD")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(pUCCD, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_pUCCSD")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(pUCCSD, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_comp_UCCS")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(comp_UCCS, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_comp_pUCCD")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(comp_pUCCD, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_comp_pUCCSD")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(comp_pUCCSD, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_fci")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(fci, file)

# name = now.strftime(f"%d-%m-%y_%H-%M_LiH_hf")
# with open( os.path.join("saved_calculations", f"{name}.pkl"), 'wb') as file:
#     pickle.dump(hf, file)

# %%
# classical_CCSD = []
# classical_CCSD_T = []

# fci = []
# hf = []

# for r in lin:

#     print("-"*20, f"\nr = {r}\n", "-"*20)

#     mol = gto.Mole()
#     mol.atom = f"H 0 0 0; Li 0 0 {r}"
#     mol.basis = 'sto-3g'
#     mol.spin=0
#     mol.build()

#     # fci
#     print("fci")
#     mf = mol.RHF().run()
#     cisolver = FCI(mf)
#     fci.append(cisolver.kernel()[0])

#     # hf
#     print("hf")
#     mf = scf.RHF(mol)
#     hf.append(mf.kernel())

#     # cc
#     mf = scf.HF(mol).run()
#     # Note that the line following these comments could be replaced by
#     # mycc = cc.CCSD(mf)
#     # mycc.kernel()
#     mycc = cc.CCSD(mf).run()
#     classical_CCSD.append(mycc.e_tot)
#     et = mycc.ccsd_t()
#     classical_CCSD_T.append(mycc.e_tot + et)

# %%
# with open("saved_calculations/21-06-23_17-19_LiH_pUCCSD.pkl", "rb") as file:
#     pUCCSD = pickle.load(file)

# %%
# for r, f, csd, csdt, sd in zip( lin, fci, classical_CCSD, classical_CCSD_T, pUCCSD):
#     print(f"r = {r}\nfci = {round(f,6)} | pUCCSD = {round(sd,6)} | diff = {round( sd - f, 6)}")
#     print(f"r = {r}\nfci = {round(f,6)} | CCSD = {round(csd,6)} | diff = {round( csd - f, 6)}")
#     print(f"r = {r}\nfci = {round(f,6)} | CCSDT = {round(csdt,6)} | diff = {round( csdt - f, 6)}")
#     print("\n")

# %%
import matplotlib.pyplot as plt

# Set font size
plt.rcParams['font.size'] = 27

plt.figure(figsize=(16, 9))

# plt.plot(lin, UCCS, label="UCCS ansatz", lw=3)
# plt.plot(lin, pUCCSD, label="pUCCSD ansatz")

# plt.plot(lin, classical_CCSD, label="pCCD", ls="-", lw=3)
# plt.plot(lin, classical_CCSD_T, label="CCSD_T")


# plt.plot(lin, comp_UCCS, label="comp_UCCS ansatz")
# plt.plot(lin, comp_pUCCD, label="comp_pUCCD ansatz")
# plt.plot(lin, comp_pUCCSD, label="comp_pUCCSD ansatz")

plt.plot(lin, hf, label="HF, UCCS", ls="-", lw=3)
plt.plot(lin, fci, label="FCI, pCCD, 1-UpCCGSD", ls="-", lw=3)

# plt.plot(lin, cid, label="cid", ls="-.")

# plt.plot(lin, pUCCD, label="1-UpCCGSD ansatz", ls="-.", lw=3)


plt.legend()

# plt.title("Comparison of dissociation curves of H2")
plt.xlabel('bond length [Å]')
plt.ylabel('E [Ha]')

plt.savefig("QC_UCC_HH.pdf")

# %% [markdown]
# ## Noisy computations

# %% [markdown]
# The noisy calculations are performed in tequila, which fails to create a molecule for certain bond lengths. Because of this the calculations are save in a pickle file. When a calculation fails, the previous ones can be retrieved from the pickle files, and after adjusting the linspace, the calculations can be continued. (if tequila fails for r=4.5, try r=4.50001)

# %%
# # classical_CC = []
# # UCCS = []
# pUCCD_noisy = []
# # pUCCSD = []

# for r in lin:

#     print("-"*20, f"\nr = {r}\n", "-"*20)

#     driver = PySCFDriver(atom=f"H 0 0 0; H 0 0 {r}", spin=0, basis="sto-3g")
#     mol = driver.run()

#     # # singles
#     # print("UCCS")
#     # ansatz = qucca.CustomAnsatz(mol, singles=True)
#     # UCCS.append(qucca.solve_noisy(mol, ansatz.circuit))

#     # pair doubles
#     print("pUCCD")
#     ansatz = qucca.CustomAnsatz(mol, pair_doubles=True)
#     res = qucca.solve_noisy(mol, ansatz.circuit)
#     pUCCD_noisy.append(res)
#     print(res)

#     # # singles & pair doubles
#     # print("pUCCSD")
#     # ansatz = qucca.CustomAnsatz(mol, singles=True, pair_doubles=True)
#     # pUCCSD.append(qucca.solve_noisy(mol, ansatz.circuit))

# %%
lin = np.linspace(4.50001, 4.5, 1)

# %%
with open("pUCCD_noisy_2_2.pkl", "rb") as file:
    pUCCD_noisy_2 = pickle.load(file)

with open("real_lin_2.pkl", "rb") as file:
    real_lin = pickle.load(file)

# %%
# pUCCD_noisy_2 = []
# real_lin = []
pUCCD_noisy_2 = pUCCD_noisy_2
real_lin = real_lin

for r in lin:

    print("-"*20, f"\nr = {r}\n", "-"*20)

    # pair doubles
    print("UpCCD")
    # ansatz = qucca.CustomAnsatz(mol, pair_doubles=True)
    res = qucca.solve_noisy_2(r)
    pUCCD_noisy_2.append(res)
    print(res)
    real_lin.append(r)

    with open("pUCCD_noisy_2_2.pkl", "wb") as file:
        pickle.dump(pUCCD_noisy_2, file)

    with open("real_lin_2.pkl", "wb") as file:
        pickle.dump(real_lin, file)
# Out:
# --------------------
# r = 4.50001
#  --------------------
# UpCCD
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qiskit
# device          : fake_rome
# samples         : 1000000
# save_history    : True
# noise           : None
#
# Method          : COBYLA
# Objective       : 2 expectationvalues
#
# active variables : 1
#
# E=-0.58538011  angles= {(((0, 1),), 'D', (None, 0)): 0.0}  samples= 1000000
# E=-0.39778299  angles= {(((0, 1),), 'D', (None, 0)): 1.0}  samples= 1000000
# E=-0.74347187  angles= {(((0, 1),), 'D', (None, 0)): -1.0}  samples= 1000000
# E=-0.74683283  angles= {(((0, 1),), 'D', (None, 0)): -2.0}  samples= 1000000
# E=-0.69175912  angles= {(((0, 1),), 'D', (None, 0)): -2.5}  samples= 1000000
# E=-0.77503845  angles= {(((0, 1),), 'D', (None, 0)): -1.75}  samples= 1000000
# E=-0.75936055  angles= {(((0, 1),), 'D', (None, 0)): -1.5}  samples= 1000000
# E=-0.75978731  angles= {(((0, 1),), 'D', (None, 0)): -1.625}  samples= 1000000
# E=-0.74820798  angles= {(((0, 1),), 'D', (None, 0)): -1.8125}  samples= 1000000
# E=-0.76892915  angles= {(((0, 1),), 'D', (None, 0)): -1.71875}  samples= 1000000
# E=-0.75895260  angles= {(((0, 1),), 'D', (None, 0)): -1.765625}  samples= 1000000
# E=-0.76004051  angles= {(((0, 1),), 'D', (None, 0)): -1.7421875}  samples= 1000000
# E=-0.77369327  angles= {(((0, 1),), 'D', (None, 0)): -1.75390625}  samples= 1000000
# E=-0.75236501  angles= {(((0, 1),), 'D', (None, 0)): -1.748046875}  samples= 1000000
# E=-0.76038063  angles= {(((0, 1),), 'D', (None, 0)): -1.751}  samples= 1000000
# UCC (noisy) = -0.77503845
# SciPyResults(energy=-0.7750384477973898, history=OptimizerHistory(energies=[-0.585380111553971, -0.3977829939252797, -0.7434718693182698, -0.7468328334028382, -0.691759117799206, -0.7750384477973898, -0.7593605474063477, -0.7597873051778248, -0.7482079786364972, -0.7689291453014977, -0.7589526019308828, -0.7600405077749741, -0.7736932654273464, -0.7523650145607714, -0.7603806322349365], gradients=[], angles=[{(((0, 1),), 'D', (None, 0)): 0.0}, {(((0, 1),), 'D', (None, 0)): 1.0}, {(((0, 1),), 'D', (None, 0)): -1.0}, {(((0, 1),), 'D', (None, 0)): -2.0}, {(((0, 1),), 'D', (None, 0)): -2.5}, {(((0, 1),), 'D', (None, 0)): -1.75}, {(((0, 1),), 'D', (None, 0)): -1.5}, {(((0, 1),), 'D', (None, 0)): -1.625}, {(((0, 1),), 'D', (None, 0)): -1.8125}, {(((0, 1),), 'D', (None, 0)): -1.71875}, {(((0, 1),), 'D', (None, 0)): -1.765625}, {(((0, 1),), 'D', (None, 0)): -1.7421875}, {(((0, 1),), 'D', (None, 0)): -1.75390625}, {(((0, 1),), 'D', (None, 0)): -1.748046875}, {(((0, 1),), 'D', (None, 0)): -1.751}], energies_calls=[], gradients_calls=[], angles_calls=[]), variables={(((0, 1),), 'D', (None, 0)): -1.75}, scipy_result=     fun: -0.7603806322349365
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 15
#   status: 1
#  success: True
#        x: array([-1.751]))

# %%
# with open("noisy_CID.pkl", "rb") as file:
#     noisy_pUCCD = pickle.load(file)

# %%
with open("pUCCD_noisy_2_2.pkl", "rb") as file:
    pUCCD_noisy_2 = pickle.load(file)

with open("real_lin_2.pkl", "rb") as file:
    real_lin = pickle.load(file)

# %%
len(pUCCD_noisy_2)
# Out:
# 50

# %%
pUCCD_nois = [i.energy for i in pUCCD_noisy_2]

# %%
import matplotlib.pyplot as plt
# Set font size
plt.rcParams['font.size'] = 27

plt.figure(figsize=(16, 9))

# plt.plot(lin, UCCS, label="UCCS ansatz")
plt.plot(real_lin, pUCCD_nois, label="noisy 1-UpGCCSD ansatz", lw=2)
# plt.plot(lin, pUCCSD, label="pUCCSD ansatz")

plt.plot(lin, fci, label="FCI", ls="--", lw=2)
plt.plot(lin, hf, label="HF", ls="--", lw=2)
# plt.plot(lin, cid, label="cid", ls="-.")

plt.legend()

# plt.title("Comparison of dissociation curves of H2")
plt.xlabel('bond length [Å]')
plt.ylabel('E [Ha]')

plt.savefig("QC_UCC_HH_noisy.pdf")
